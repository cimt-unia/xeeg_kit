# %%
# Bel 280 Headset Visualization

import mne
from xeeg_kit import load_bel_channel_map, plot_headset_3d

# %%
# Load the bundled map (Instant, no GPSC parsing required)

map_df = load_bel_channel_map() 

# Inspect Regions
print("\n--- Available Channels by Region ---")
print(map_df['region'].unique())

print("\n--- Example: Occipital Channels ---")
occipital_chs = map_df[map_df['region'] == 'Occipital']['name'].tolist()
print(f"Found {len(occipital_chs)} Occipital channels.")
print(occipital_chs[:5]) # Print first 5
# Out:
# 📂 Loading bundled map from: /mnt/movement/users/jaizor/.local/lib/python3.13/site-packages/xeeg_kit/data/bel_280_channel_map.csv
#
# --- Available Channels by Region ---
# ['Orbital/Eye' 'Lateral-Inferior/Jaw' 'Prefrontal' 'Inferior-Frontal/Jaw'
#  'Temporal' 'Fronto-Temporal' 'Central' 'Cerebellar/Neck' 'Occipital'
#  'Parietal']
#
# --- Example: Occipital Channels ---
# Found 45 Occipital channels.
# ['E104', 'E105', 'E106', 'E107', 'E108']

# %%
# Visualize the full headset
plot_headset_3d(map_df)
# Out:
# ✅ Interactive 3D headset plot saved to: bel_280_headset_layout.html
